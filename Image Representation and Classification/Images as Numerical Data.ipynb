# %% [markdown]
# # Images as Grids of Pixels

# %% [markdown]
# ### Import Resources

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\asus\anaconda3\envs\analysis_env\lib\site-packages (from opencv-python) (2.2.5)
# Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.0 MB 5.6 MB/s eta 0:00:07
#    ------ --------------------------------- 6.8/39.0 MB 24.6 MB/s eta 0:00:02
#    ------------------------- -------------- 24.4/39.0 MB 49.7 MB/s eta 0:00:01
#    ---------------------------------------- 39.0/39.0 MB 56.3 MB/s  0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.12.0.88

# %%
import numpy as np
import matplotlib.image as mpimg # for reading images

import matplotlib.pyplot as plt
import cv2 # computer vision library

# %matplotlib inline

# %% [markdown]
# ### Read and Display the Image

# %%
# Read in the image
image = mpimg.imread('images/waymo_car.jpg')

# Print out the image dimensions
print('Image dimensions:', image.shape)

# Change from color to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap = 'gray')
# Out:
# Image dimensions: (427, 640, 3)

# %%
# Print specific grayscale pixel values 
# For instance: Pixel value at x = 400 and y = 300 (on the body of the car)

x = 400
y = 300
print(gray_image[y, x])
# Out:
# 159

# %%
# Find the maximum and minimum grayscale values in the image

max_val = np.amax(gray_image)
min_val = np.amin(gray_image)

print('Max: ', max_val)
print('Min: ', min_val)
# Out:
# Max:  255
# Min:  2

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[0, 20, 30, 150, 120], 
                       [50, 180, 85, 40, 90],
                       [240, 100, 50, 255, 10],
                       [30, 0, 75, 190, 220]])
# To show the pixel grid use matshow
plt.matshow(tiny_image, cmap = 'gray')

smiley_face = np.array([[0, 150, 0, 150, 0], 
                       [0, 0, 0, 0, 0],
                       [0, 150, 0, 150, 0],
                       [0, 150, 150, 150, 0]])
# To show the pixel grid use matshow
plt.matshow(smiley_face, cmap = 'gray')
